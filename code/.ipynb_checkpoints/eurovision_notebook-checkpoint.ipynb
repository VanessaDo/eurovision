# %% [markdown]
# # Eurovision Analysis (Part I)
#
# This notebook explores voting patterns in the Eurovision Song Contest finals from 2016 to 2021. The focus of the analysis is on comparing the differences between the musical tastes of televoters and the musical jury in each country.

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
import pandas as pd
import plotly.express as px
import re
import seaborn as sns
from sklearn import preprocessing, decomposition, cluster, manifold
from sklearn.metrics.pairwise import cosine_similarity

# %%
#%pip install "notebook>=5.3" "ipywidgets>=7.5"

# %%
pd.set_option('display.max_rows', None) # increase number of rows displayed
pd.set_option('display.max_columns', None)
pd.set_option('display.float_format', lambda x: '%.3f' % x)
np.set_printoptions(suppress=True)

# %% [markdown]
# ## 1. Data Wrangling

# %%
def read_file(file_name):
    """Reads csv file and returns a pandas dataframe"""
    df = pd.read_csv(file_name)
    return df

# %%
data = read_file('../data/eurovision_1957-2021.csv')
data.head()
# Out:
#    Unnamed: 0         Edition  Year                 Points type    From  \
# 0       0.000  rotterdam-2021  2021  Points given by televoters  cyprus
# 1       1.000  rotterdam-2021  2021  Points given by televoters  cyprus
# 2       2.000  rotterdam-2021  2021  Points given by televoters  cyprus
# 3       3.000  rotterdam-2021  2021  Points given by televoters  cyprus
# 4       4.000  rotterdam-2021  2021  Points given by televoters  cyprus
#
#          To  Points
# 0    greece      12
# 1     italy      10
# 2    france       8
# 3  bulgaria       7
# 4   ukraine       6

# %%
def remove_columns(df):
    """Drop unnecessary columns of data"""
    df_clean = df.drop(columns=['Unnamed: 0','Edition'], axis=1) # remove redundant column
    return df_clean

# %%
data = remove_columns(data)    
data.head()
# Out:
#    Year                 Points type    From        To  Points
# 0  2021  Points given by televoters  cyprus    greece      12
# 1  2021  Points given by televoters  cyprus     italy      10
# 2  2021  Points given by televoters  cyprus    france       8
# 3  2021  Points given by televoters  cyprus  bulgaria       7
# 4  2021  Points given by televoters  cyprus   ukraine       6

# %%
def filter_years(df, year):
    """Retains only the data after the specified year"""
    df_filtered = df[df.Year >= year]
    return df_filtered

# %%
data = filter_years(data, 2016)
data.Year.unique()
# Out:
# array([2021, 2019, 2018, 2017, 2016])

# %%
def inspect_data(df):
    """Check for missing values, data ranges, data types and unique values
    for countries
    """
    print("Missing Values: \n", df.isnull().sum(), "\n")
    print("Summary Statistics: \n", df.describe(), "\n")
    print("Data Types: \n", df.dtypes)
    print("Unique Values: 'From' \n", df['From'].unique(), "\n")
    print("Unique Values: 'To' \n", df['To'].unique(), "\n")

# %%
inspect_data(data)
# Out:
# Missing Values:
#  Year           0
# Points type    0
# From           0
# To             0
# Points         0
# dtype: int64
#
# Summary Statistics:
#            Year   Points
# count 2600.000 2600.000
# mean  2018.200    5.800
# std      1.721    3.341
# min   2016.000    1.000
# 25%   2017.000    3.000
# 50%   2018.000    5.500
# 75%   2019.000    8.000
# max   2021.000   12.000
#
# Data Types:
#  Year            int64
# Points type    object
# From           object
# To             object
# Points          int64
# dtype: object
# Unique Values: 'From'
#  ['cyprus' 'albania' 'israel' 'belgium' 'russia' 'malta' 'portugal'
#  'serbia' 'united-kingdom' 'greece' 'switzerland' 'iceland' 'spain'
#  'moldova' 'germany' 'finland' 'bulgaria' 'lithuania' 'ukraine' 'france'
#  'azerbaijan' 'norway' 'the-netherlands' 'italy' 'sweden' 'san-marino'
#  'czech-republic' 'denmark' 'slovenia' 'estonia' 'belarus' 'australia'
#  'austria' 'hungary' 'ireland' 'poland' 'armenia' 'croatia' 'romania'
#  'latvia' 'georgia' 'north-macedonia']
#
# Unique Values: 'To'
#  ['greece' 'italy' 'france' 'bulgaria' 'ukraine' 'lithuania' 'finland'
#  'russia' 'israel' 'malta' 'belgium' 'switzerland' 'portugal' 'moldova'
#  'cyprus' 'sweden' 'san marino' 'azerbaijan' 'serbia' 'iceland' 'norway'
#  ' cyprus' 'albania' 'the netherlands' 'spain' 'sweden ' ' greece'
#  'north macedonia' 'australia' ' australia' 'estonia' 'slovenia' 'denmark'
#  'belarus' 'germany' ' switzerland' 'czech republic' 'united kingdom'
#  ' france' 'north macedonia ' 'hungary' 'austria' 'ireland' 'italy '
#  'romania' 'croatia' ' sweden' 'armenia' 'poland' 'austria ' 'georgia'
#  'latvia' 'latvia ']

# %%
def clean_names(df):
    """Remove hidden blank spaces and dashes from names in dataframe"""
    df['From'] = df['From'].apply(lambda row: re.sub('-', ' ', row.strip()))
    df['To'] = df['To'].apply(lambda row: re.sub('-', ' ', row.strip()))
    df['Points type'] = df['Points type'].apply(lambda row: row.strip())
    return df

# %%
data = clean_names(data)

# %%
def check_sum(data):
    """Check the points have been recorded correctly per year and country"""
    df = data[['Year','From','Points']].groupby(['Year']).sum()
    return df

# %%
check_sum(data)
# Out:
#       Points
# Year
# 2016    3016
# 2017    3016
# 2018    3016
# 2019    3016
# 2021    3016

# %%
def create_additional_columns(df):
    """Create identifier columns for each voter type and country combination
    and for voter type, and an adjusted points column
    """
    df.insert(1, 'voter', df.apply(lambda row: label_voter_type(row), axis=1))
    df.insert(1, 'voter_country', df['voter'] + '_' + df['From'])
    df['adjusted_points'] = df.apply(lambda row: adjusted_points(row), axis=1)
    return df

def label_voter_type(row):
    """Returns the voter type"""
    if re.search(r'televoter', row['Points type']):
        return 'televoter'
    elif re.search(r'jury', row['Points type']):
        return 'jury'
    
def adjusted_points(row):
    """Adjusts the 10 and 12 points to 9 and 10 (so there's even 
    spacing between points)
    """
    if row['Points'] == 12:
        return 10
    elif row['Points'] == 10:
        return 9
    else:
        return row['Points']

# %%
data = create_additional_columns(data)
data.head(20)
# Out:
#     Year     voter_country      voter                 Points type    From  \
# 0   2021  televoter_cyprus  televoter  Points given by televoters  cyprus
# 1   2021  televoter_cyprus  televoter  Points given by televoters  cyprus
# 2   2021  televoter_cyprus  televoter  Points given by televoters  cyprus
# 3   2021  televoter_cyprus  televoter  Points given by televoters  cyprus
# 4   2021  televoter_cyprus  televoter  Points given by televoters  cyprus
# 5   2021  televoter_cyprus  televoter  Points given by televoters  cyprus
# 6   2021  televoter_cyprus  televoter  Points given by televoters  cyprus
# 7   2021  televoter_cyprus  televoter  Points given by televoters  cyprus
# 8   2021  televoter_cyprus  televoter  Points given by televoters  cyprus
# 9   2021  televoter_cyprus  televoter  Points given by televoters  cyprus
# 10  2021       jury_cyprus       jury    Points given by the jury  cyprus
# 11  2021       jury_cyprus       jury    Points given by the jury  cyprus
# 12  2021       jury_cyprus       jury    Points given by the jury  cyprus
# 13  2021       jury_cyprus       jury    Points given by the jury  cyprus
# 14  2021       jury_cyprus       jury    Points given by the jury  cyprus
# 15  2021       jury_cyprus       jury    Points given by the jury  cyprus
# 16  2021       jury_cyprus       jury    Points given by the jury  cyprus
# 17  2021       jury_cyprus       jury    Points given by the jury  cyprus
# 18  2021       jury_cyprus       jury    Points given by the jury  cyprus
# 19  2021       jury_cyprus       jury    Points given by the jury  cyprus
#
#              To  Points  adjusted_points
# 0        greece      12               10
# 1         italy      10                9
# 2        france       8                8
# 3      bulgaria       7                7
# 4       ukraine       6                6
# 5     lithuania       5                5
# 6       finland       4                4
# 7        russia       3                3
# 8        israel       2                2
# 9         malta       1                1
# 10       greece      12               10
# 11        malta      10                9
# 12        italy       8                8
# 13       france       7                7
# 14       russia       6                6
# 15     bulgaria       5                5
# 16      belgium       4                4
# 17      finland       3                3
# 18  switzerland       2                2
# 19     portugal       1                1

# %%
data = data.drop(columns=['Points type'], axis=1)
data.head()
# Out:
#    Year     voter_country      voter    From        To  Points  \
# 0  2021  televoter_cyprus  televoter  cyprus    greece      12
# 1  2021  televoter_cyprus  televoter  cyprus     italy      10
# 2  2021  televoter_cyprus  televoter  cyprus    france       8
# 3  2021  televoter_cyprus  televoter  cyprus  bulgaria       7
# 4  2021  televoter_cyprus  televoter  cyprus   ukraine       6
#
#    adjusted_points
# 0               10
# 1                9
# 2                8
# 3                7
# 4                6

# %% [markdown]
# ## 2. EDA - Points Difference

# %% [markdown]
# We begin by comparing the overall points difference between televoters and the jury of each country, for each year

# %%
def plot_points_map(df, year):
    """Plot points distribution for televoters and jury"""
    # create matrix of votes from/to by televoter
    televoter_df = df[(df.Year==year) & (df.voter=='televoter')]
    televoter_df_pivot = (televoter_df.pivot_table(
        index='To', columns='From', values='Points', fill_value=0, aggfunc='sum'))
    # identify missing values and fill these in
    missing_countries = list(set(televoter_df.From) - set(televoter_df.To))
    for country in missing_countries:
        televoter_df_pivot.loc[country] = [0] * len(televoter_df_pivot.columns)
    televoter_df_pivot = televoter_df_pivot.sort_index()
    # create matrix of votes from/to by jury
    jury_df = df[(df.Year==year) & (df.voter=='jury')]
    jury_df_pivot = (jury_df.pivot_table(
        index='To', columns='From', values='Points', fill_value=0, aggfunc='sum')) 
    # identify missing values and fill these in
    missing_countries = list(set(jury_df.From) - set(jury_df.To))
    for country in missing_countries:
        jury_df_pivot.loc[country] = [0] * len(jury_df_pivot.columns)
    jury_df_pivot = jury_df_pivot.sort_index()    
    # plot chart
    fig, (ax1, ax2) = plt.subplots(1,2)      
    fig.set_size_inches(16,6)    
    sns.heatmap(televoter_df_pivot, xticklabels=True, yticklabels=True, cmap="Reds", ax=ax1)
    sns.heatmap(jury_df_pivot, xticklabels=True, yticklabels=True, cmap="Blues", ax=ax2)   
    ax1.set(title='Televoter Votes for {}'.format(year), xlabel="Points From", ylabel="Points To")
    ax2.set(title='Jury Votes for {}'.format(year), xlabel="Points From", ylabel="Points To")
    plt.show()

# %%
years = [2016, 2017, 2018, 2019, 2021]
for year in years:
    plot_points_map(data, year)

# %%
def points_diff(df, year):
    """Calculate the difference in points between televoter and jury by
    country
    """
    df_filtered_by_year = df[df.Year==year]
    df_pivot = (df_filtered_by_year.pivot_table(
        index='To', columns=['From','voter'], values='Points', 
        aggfunc='sum', fill_value=0))
    # calculate difference in values between the voter types
    df_diff = (df_pivot.loc[:, pd.IndexSlice[:, 'televoter']]
        - df_pivot.loc[:,pd.IndexSlice[:,'jury']].values)
    df_diff = df_diff.droplevel('voter', axis=1)
    # get missing list of countries with zero points
    missing_countries = list(set(df_filtered_by_year.From.unique())
        - set(df_filtered_by_year.To.unique()))
    # add missing countries to data frame
    for country in missing_countries:
        df_diff.loc[country] = [0]*len(df_diff.columns)   
    df_diff = df_diff.sort_index()
    df_diff_sum = pd.DataFrame(df_diff.sum(axis=1), columns=['Diff']).sort_values(by='Diff', ascending=False).reset_index()
    fig, (ax1, ax2) = plt.subplots(1, 2)
    fig.set_size_inches(15,6)
    sns.barplot(y='To',x='Diff', palette="vlag_r", data=df_diff_sum, ax=ax1)
    sns.heatmap(
        df_diff, xticklabels=df_diff.columns, yticklabels=df_diff.columns, 
        vmin=-12, vmax=12, cmap="vlag", ax=ax2)
    ax1.set(title="Aggregate Points Difference for {}".format(year), xlabel="Points Difference", ylabel="Points To", xlim=(-180,180))
    ax2.set(title="Country Level Points Difference for {}".format(year), xlabel="Points From", ylabel="Points To")
    plt.subplots_adjust(wspace=0.4)
    plt.show()

# %%
years = [2016, 2017, 2018, 2019, 2021]
for year in years:
    points_diff(data, year)

# %% [markdown]
# ##### Comments
# - In each year, there are songs with a strong difference in opinion between the jury and televoters across countries (represented by horizontal rows with a darker colour)
# - From 2017 to 2019, there was a 'halo' effect for Sweden, with the jury votes for Sweden generally higher than the televoter votes across multiple countries
# - The strongest differences in jury/televoter opinion were observed for Russia's entry in 2016 and Norway's entry in 2019
# - When Australia joined the Eurovision Song Contest officially in 2016, the jury scores were generally higher than the televoters and this pattern continued to 2018. However, there was a shift in 2019 with 13 countries having a higher televoter scores than the general public
# - There are some interesting details to extract from the heatmap, such as the jury of the Czech Republic favouring Sweden more than the Czech public in the past 3 contests they have been in.

# %% [markdown]
# ## 3. Cosine SImilarity

# %% [markdown]
# This analysis explores similarities in voting patterns between televoters and juries.
#
# We model the voting preferences of televoters and the juries as vectors. Cosine distances are computed to compare similarities, providing a score between 0 and 1 (scores closer to 1 indicate a higher similarity, as the angle between the vectors is closer to 0). To ensure the cosine distances are not skewed by higher points awarded to the top 2 countries, adjusted points have been used (so 10 points is scaled down to 9, and 12 points is scaled down to 10).

# %%
def create_df_wide_by_year(df, year):
    """Adds the missing combinations of countries from/to and fills value
    with a zero"""
    df_filtered_by_year = df[df.Year==year].drop(columns=['Points'], axis=1)
    df_wide = (df_filtered_by_year.pivot_table(
        index=['voter_country','voter','From'],
        columns=['To'],
        values='adjusted_points',
        aggfunc='sum',
        fill_value=0))
    # get missing list of countries with zero points
    missing_countries = list(set(df_filtered_by_year.From.unique())
        - set(df_filtered_by_year.To.unique()))
    # add missing countries to data frame
    for country in missing_countries:
        df_wide[country] = 0    
    # re-sort the columns in dataframe
    df_wide = df_wide[df_wide.columns.sort_values()]
    np_matrix = df_wide.to_numpy()
    # get the names of the countries
    country_labels = df_wide.columns    
    # get the labels for voter_country combination
    voter_country_labels = df_wide.index.get_level_values(0)
    return df_wide, np_matrix, country_labels, voter_country_labels

# %%
def calc_cosine_similarity(np_matrix, voter_country_labels, country_labels):
    """Calculate cosine similarity matrix on voter preferences"""
    cosine_sim_matrix = cosine_similarity(np_matrix)
    cosine_sim_matrix_len = cosine_sim_matrix.shape[0]
    i1 = int(cosine_sim_matrix_len/2) # index to only select first n/2 entries
    i2 = cosine_sim_matrix_len # index to select up to the end of the matrix
    # similarity scores for all voter-country combinations
    df_cosine_sim_all = pd.DataFrame(cosine_sim_matrix,
        columns=voter_country_labels,
        index=voter_country_labels)
    # similarity scores for televoters vs jury
    df_cosine_sim_tvj = df_cosine_sim_all.iloc[i1:i2,0:i1]
    # similarity scores for voters vs jury (per country)
    list_diagonals_tvj = ([df_cosine_sim_tvj.iat[n, n]
        for n in range(len(df_cosine_sim_tvj))])
    df_tvj_diagonals = pd.DataFrame(
        list(zip(list(country_labels),
        list_diagonals_tvj)), columns=['Country','Similarity'])
    return df_cosine_sim_all, df_cosine_sim_tvj, df_tvj_diagonals

# %%
def plot_similarity(df_cosine_sim_tvj, df_tvj_diagonals, year):
    """Plot heatmap of similarity matrix"""
    
    col_ref = [re.sub('jury_','',col) for col in list(df_cosine_sim_tvj.columns)]
    index_ref = [re.sub('televoter_','',ind) for ind in list(df_cosine_sim_tvj.index)]        
    fig, (ax1, ax2) = plt.subplots(1, 2)
    fig.set_size_inches(16,6)
    sns.heatmap(
        df_cosine_sim_tvj, 
        xticklabels=col_ref, yticklabels=index_ref, 
        vmin=0, vmax=1, ax=ax1)
    ax1.set(title="Similarity Matrix for {}".format(year), 
        xlabel="Jury Vote", ylabel="Televoter Vote")
    country_order = df_tvj_diagonals.sort_values(by="Similarity", ascending=False)['Country']
    colour_order = df_tvj_diagonals.sort_values(by="Similarity", ascending=False)['Similarity']
    sns.barplot(y="Country", x="Similarity", data=df_tvj_diagonals,
        order=country_order, palette=mpl.cm.magma(colour_order), ax=ax2)
    ax2.set(title="Similarity Scores between Televoters and Jury by Country for {}".format(year), 
        xlabel="Similarity Score", xlim=(0,1))
    plt.subplots_adjust(wspace=0.3)
    plt.show()

# %%
def print_top_bottom_n_similarity(df_wide, df_tvj_diagonals, n=3):
    """Displays the voting patterns for the top/bottom n countries"""
    
    tbl = df_tvj_diagonals.sort_values(by='Similarity', ascending=False)
    top_n_countries = tbl.head(n)['Country']
    bottom_n_countries = tbl.tail(n)['Country']
    
    print('Top {} Countries with Similar Scores'.format(n))
    print(list(top_n_countries))    
    for country in top_n_countries:
        df = df_wide.loc[pd.IndexSlice[:,:,country],:]
        df = df.loc[:,(df!=0).any(axis=0)]
        print(df.T)
    
    print('Bottom {} Countries with Similar Scores'.format(n))
    print(list(bottom_n_countries))
    for country in bottom_n_countries:
        df = df_wide.loc[pd.IndexSlice[:,:,country],:]
        df = df.loc[:,(df!=0).any(axis=0)]
        print(df.T)

# %%
years = [2016, 2017, 2018, 2019, 2021]
df_cosinesim_by_year_list = []

for year in years:
    df_wide, np_matrix, country_labels, voter_country_labels = create_df_wide_by_year(data, year)
    df_cosine_sim_all, df_cosine_sim_tvj, df_tvj_diagonals = calc_cosine_similarity(np_matrix, voter_country_labels, country_labels)
    plot_similarity(df_cosine_sim_tvj, df_tvj_diagonals, year)
#    print_top_bottom_n_similarity(df_wide, df_tvj_diagonals, n=3)    
    # collect the similarity scores by country by year for temporal analysis
    df_tvj_diagonals['Year'] = year
    df_cosinesim_by_year_list.append(df_tvj_diagonals)

# %% [markdown]
# ##### Comments
# - When the cosine similarities are compared, it can be observed that the jury and televoters of Cyprus have similar voting patterns in most years.
# - In contrast, the jury and televoters of Italy generally have the least similar voting patterns.
# - In 2017, the Bulgarian jury had the most different voting patterns compared with televoters - their top points were awarded to Austria and no points were awarded to Portugal

# %%
# examine some of the biggest differences
df_wide, *_ = create_df_wide_by_year(data, 2017)
jury = df_wide.loc[pd.IndexSlice['jury_bulgaria',:,:],:]
televoter = df_wide.loc[pd.IndexSlice[:,'televoter',:],:]
combined = pd.concat([jury, televoter], axis=0)
combined.loc[:,(combined!=0).any(axis=0)]
# Out:
# To                                                   armenia  australia  \
# voter_country             voter     From
# jury_bulgaria             jury      bulgaria               4          0
# televoter_armenia         televoter armenia                0          0
# televoter_australia       televoter australia              0          0
# televoter_austria         televoter austria                0          0
# televoter_azerbaijan      televoter azerbaijan             0          0
# televoter_belarus         televoter belarus                0          0
# televoter_belgium         televoter belgium                0          0
# televoter_bulgaria        televoter bulgaria               0          0
# televoter_croatia         televoter croatia                0          0
# televoter_cyprus          televoter cyprus                 1          0
# televoter_denmark         televoter denmark                0          2
# televoter_france          televoter france                 6          0
# televoter_germany         televoter germany                0          0
# televoter_greece          televoter greece                 2          0
# televoter_hungary         televoter hungary                0          0
# televoter_israel          televoter israel                 0          0
# televoter_italy           televoter italy                  0          0
# televoter_moldova         televoter moldova                0          0
# televoter_norway          televoter norway                 0          0
# televoter_poland          televoter poland                 0          0
# televoter_portugal        televoter portugal               0          0
# televoter_romania         televoter romania                0          0
# televoter_spain           televoter spain                  0          0
# televoter_sweden          televoter sweden                 0          0
# televoter_the netherlands televoter the netherlands        0          0
# televoter_ukraine         televoter ukraine                0          0
# televoter_united kingdom  televoter united kingdom         0          0
#
# To                                                   austria  azerbaijan  \
# voter_country             voter     From
# jury_bulgaria             jury      bulgaria              10           5
# televoter_armenia         televoter armenia                0           0
# televoter_australia       televoter australia              0           0
# televoter_austria         televoter austria                0           0
# televoter_azerbaijan      televoter azerbaijan             0           0
# televoter_belarus         televoter belarus                0           0
# televoter_belgium         televoter belgium                0           0
# televoter_bulgaria        televoter bulgaria               0           0
# televoter_croatia         televoter croatia                0           0
# televoter_cyprus          televoter cyprus                 0           0
# televoter_denmark         televoter denmark                0           0
# televoter_france          televoter france                 0           0
# televoter_germany         televoter germany                0           0
# televoter_greece          televoter greece                 0           0
# televoter_hungary         televoter hungary                0           0
# televoter_israel          televoter israel                 0           0
# televoter_italy           televoter italy                  0           0
# televoter_moldova         televoter moldova                0           9
# televoter_norway          televoter norway                 0           0
# televoter_poland          televoter poland                 0           0
# televoter_portugal        televoter portugal               0           0
# televoter_romania         televoter romania                0           0
# televoter_spain           televoter spain                  0           0
# televoter_sweden          televoter sweden                 0           0
# televoter_the netherlands televoter the netherlands        0           0
# televoter_ukraine         televoter ukraine                0           0
# televoter_united kingdom  televoter united kingdom         0           0
#
# To                                                   belarus  belgium  \
# voter_country             voter     From
# jury_bulgaria             jury      bulgaria               2        0
# televoter_armenia         televoter armenia                0        5
# televoter_australia       televoter australia              0        4
# televoter_austria         televoter austria                0        8
# televoter_azerbaijan      televoter azerbaijan             0        4
# televoter_belarus         televoter belarus                0        6
# televoter_belgium         televoter belgium                0        0
# televoter_bulgaria        televoter bulgaria               0        4
# televoter_croatia         televoter croatia                0        5
# televoter_cyprus          televoter cyprus                 0        2
# televoter_denmark         televoter denmark                0        6
# televoter_france          televoter france                 0        8
# televoter_germany         televoter germany                0        9
# televoter_greece          televoter greece                 0        5
# televoter_hungary         televoter hungary                0        8
# televoter_israel          televoter israel                 2        6
# televoter_italy           televoter italy                  0        2
# televoter_moldova         televoter moldova                1        2
# televoter_norway          televoter norway                 0        7
# televoter_poland          televoter poland                 4       10
# televoter_portugal        televoter portugal               0        9
# televoter_romania         televoter romania                0        5
# televoter_spain           televoter spain                  0        4
# televoter_sweden          televoter sweden                 0       10
# televoter_the netherlands televoter the netherlands        0        9
# televoter_ukraine         televoter ukraine                8        5
# televoter_united kingdom  televoter united kingdom         0        3
#
# To                                                   bulgaria  croatia  \
# voter_country             voter     From
# jury_bulgaria             jury      bulgaria                0        0
# televoter_armenia         televoter armenia                 7        0
# televoter_australia       televoter australia               5        1
# televoter_austria         televoter austria                 7        4
# televoter_azerbaijan      televoter azerbaijan             10        0
# televoter_belarus         televoter belarus                10        0
# televoter_belgium         televoter belgium                 8        0
# televoter_bulgaria        televoter bulgaria                0        1
# televoter_croatia         televoter croatia                 8        0
# televoter_cyprus          televoter cyprus                  9        0
# televoter_denmark         televoter denmark                 9        0
# televoter_france          televoter france                  4        0
# televoter_germany         televoter germany                 5        8
# televoter_greece          televoter greece                  9        0
# televoter_hungary         televoter hungary                10        5
# televoter_israel          televoter israel                  9        0
# televoter_italy           televoter italy                   8        6
# televoter_moldova         televoter moldova                 8        0
# televoter_norway          televoter norway                  8        1
# televoter_poland          televoter poland                  8        1
# televoter_portugal        televoter portugal                8        0
# televoter_romania         televoter romania                 8        3
# televoter_spain           televoter spain                   9        0
# televoter_sweden          televoter sweden                  7        2
# televoter_the netherlands televoter the netherlands         8        3
# televoter_ukraine         televoter ukraine                 2        0
# televoter_united kingdom  televoter united kingdom         10        5
#
# To                                                   cyprus  denmark  france  \
# voter_country             voter     From
# jury_bulgaria             jury      bulgaria              0        0       0
# televoter_armenia         televoter armenia              10        0       8
# televoter_australia       televoter australia             0        8       0
# televoter_austria         televoter austria               0        0       0
# televoter_azerbaijan      televoter azerbaijan            0        0       5
# televoter_belarus         televoter belarus               0        0       4
# televoter_belgium         televoter belgium               0        0       3
# televoter_bulgaria        televoter bulgaria              3        0      10
# televoter_croatia         televoter croatia               0        0       3
# televoter_cyprus          televoter cyprus                0        0       3
# televoter_denmark         televoter denmark               0        0       0
# televoter_france          televoter france                0        0       0
# televoter_germany         televoter germany               0        0       0
# televoter_greece          televoter greece               10        0       4
# televoter_hungary         televoter hungary               2        0       1
# televoter_israel          televoter israel                0        0       4
# televoter_italy           televoter italy                 0        0       1
# televoter_moldova         televoter moldova               0        0       5
# televoter_norway          televoter norway                0        0       0
# televoter_poland          televoter poland                0        0       0
# televoter_portugal        televoter portugal              0        0       6
# televoter_romania         televoter romania               0        0       4
# televoter_spain           televoter spain                 0        0       3
# televoter_sweden          televoter sweden                0        0       0
# televoter_the netherlands televoter the netherlands       0        0       0
# televoter_ukraine         televoter ukraine               0        0       6
# televoter_united kingdom  televoter united kingdom        0        0       0
#
# To                                                   greece  hungary  israel  \
# voter_country             voter     From
# jury_bulgaria             jury      bulgaria              6        0       8
# televoter_armenia         televoter armenia               1        0       0
# televoter_australia       televoter australia             0        0       0
# televoter_austria         televoter austria               0        5       0
# televoter_azerbaijan      televoter azerbaijan            0        7       1
# televoter_belarus         televoter belarus               0        8       0
# televoter_belgium         televoter belgium               0        1       0
# televoter_bulgaria        televoter bulgaria              5        6       0
# televoter_croatia         televoter croatia               0       10       0
# televoter_cyprus          televoter cyprus               10        0       0
# televoter_denmark         televoter denmark               0        3       0
# televoter_france          televoter france                0        2       3
# televoter_germany         televoter germany               0        3       0
# televoter_greece          televoter greece                0        0       0
# televoter_hungary         televoter hungary               0        0       0
# televoter_israel          televoter israel                0        1       0
# televoter_italy           televoter italy                 0        4       0
# televoter_moldova         televoter moldova               7        0       0
# televoter_norway          televoter norway                0        4       0
# televoter_poland          televoter poland                0        5       0
# televoter_portugal        televoter portugal              0        2       0
# televoter_romania         televoter romania               1        9       0
# televoter_spain           televoter spain                 0        0       0
# televoter_sweden          televoter sweden                0        4       0
# televoter_the netherlands televoter the netherlands       0        6       0
# televoter_ukraine         televoter ukraine               0        4       0
# televoter_united kingdom  televoter united kingdom        0        1       0
#
# To                                                   italy  moldova  norway  \
# voter_country             voter     From
# jury_bulgaria             jury      bulgaria             0        0       0
# televoter_armenia         televoter armenia              4        6       0
# televoter_australia       televoter australia            2       10       0
# televoter_austria         televoter austria              6        3       0
# televoter_azerbaijan      televoter azerbaijan           6        9       0
# televoter_belarus         televoter belarus              0        9       5
# televoter_belgium         televoter belgium              5        7       0
# televoter_bulgaria        televoter bulgaria             0        9       0
# televoter_croatia         televoter croatia              7        4       0
# televoter_cyprus          televoter cyprus               8        6       0
# televoter_denmark         televoter denmark              0        8       7
# televoter_france          televoter france               5        7       0
# televoter_germany         televoter germany              4        7       0
# televoter_greece          televoter greece               7        6       0
# televoter_hungary         televoter hungary              4        9       0
# televoter_israel          televoter israel               8        5       0
# televoter_italy           televoter italy                0       10       0
# televoter_moldova         televoter moldova              4        0       0
# televoter_norway          televoter norway               2        6       0
# televoter_poland          televoter poland               0        6       0
# televoter_portugal        televoter portugal             4       10       0
# televoter_romania         televoter romania              6       10       0
# televoter_spain           televoter spain                8        6       0
# televoter_sweden          televoter sweden               1        8       6
# televoter_the netherlands televoter the netherlands      2        5       0
# televoter_ukraine         televoter ukraine              0       10       1
# televoter_united kingdom  televoter united kingdom       2        6       0
#
# To                                                   poland  portugal  \
# voter_country             voter     From
# jury_bulgaria             jury      bulgaria              7         0
# televoter_armenia         televoter armenia               0         9
# televoter_australia       televoter australia             0         7
# televoter_austria         televoter austria               2        10
# televoter_azerbaijan      televoter azerbaijan            0         8
# televoter_belarus         televoter belarus               0         7
# televoter_belgium         televoter belgium               4        10
# televoter_bulgaria        televoter bulgaria              0         7
# televoter_croatia         televoter croatia               0         9
# televoter_cyprus          televoter cyprus                0         7
# televoter_denmark         televoter denmark               0         5
# televoter_france          televoter france                1        10
# televoter_germany         televoter germany               2        10
# televoter_greece          televoter greece                0         8
# televoter_hungary         televoter hungary               0         7
# televoter_israel          televoter israel                0        10
# televoter_italy           televoter italy                 3         5
# televoter_moldova         televoter moldova               0         6
# televoter_norway          televoter norway                3        10
# televoter_poland          televoter poland                0         9
# televoter_portugal        televoter portugal              0         0
# televoter_romania         televoter romania               0         7
# televoter_spain           televoter spain                 0        10
# televoter_sweden          televoter sweden                5         9
# televoter_the netherlands televoter the netherlands       1        10
# televoter_ukraine         televoter ukraine               0         9
# televoter_united kingdom  televoter united kingdom        9         8
#
# To                                                   romania  spain  sweden  \
# voter_country             voter     From
# jury_bulgaria             jury      bulgaria               3      0       0
# televoter_armenia         televoter armenia                2      0       3
# televoter_australia       televoter australia              9      0       6
# televoter_austria         televoter austria                9      0       1
# televoter_azerbaijan      televoter azerbaijan             2      0       3
# televoter_belarus         televoter belarus                2      0       3
# televoter_belgium         televoter belgium                6      0       2
# televoter_bulgaria        televoter bulgaria               8      0       2
# televoter_croatia         televoter croatia                6      0       2
# televoter_cyprus          televoter cyprus                 4      0       5
# televoter_denmark         televoter denmark                4      0      10
# televoter_france          televoter france                 9      0       0
# televoter_germany         televoter germany                6      0       0
# televoter_greece          televoter greece                 1      0       3
# televoter_hungary         televoter hungary                6      0       3
# televoter_israel          televoter israel                 7      0       3
# televoter_italy           televoter italy                  9      0       0
# televoter_moldova         televoter moldova               10      0       3
# televoter_norway          televoter norway                 9      0       5
# televoter_poland          televoter poland                 7      0       3
# televoter_portugal        televoter portugal               7      5       1
# televoter_romania         televoter romania                0      0       2
# televoter_spain           televoter spain                  7      0       5
# televoter_sweden          televoter sweden                 3      0       0
# televoter_the netherlands televoter the netherlands        7      0       4
# televoter_ukraine         televoter ukraine                3      0       7
# televoter_united kingdom  televoter united kingdom         7      0       4
#
# To                                                   the netherlands  ukraine  \
# voter_country             voter     From
# jury_bulgaria             jury      bulgaria                       9        1
# televoter_armenia         televoter armenia                        0        0
# televoter_australia       televoter australia                      0        0
# televoter_austria         televoter austria                        0        0
# televoter_azerbaijan      televoter azerbaijan                     0        0
# televoter_belarus         televoter belarus                        0        1
# televoter_belgium         televoter belgium                        9        0
# televoter_bulgaria        televoter bulgaria                       0        0
# televoter_croatia         televoter croatia                        1        0
# televoter_cyprus          televoter cyprus                         0        0
# televoter_denmark         televoter denmark                        1        0
# televoter_france          televoter france                         0        0
# televoter_germany         televoter germany                        1        0
# televoter_greece          televoter greece                         0        0
# televoter_hungary         televoter hungary                        0        0
# televoter_israel          televoter israel                         0        0
# televoter_italy           televoter italy                          0        7
# televoter_moldova         televoter moldova                        0        0
# televoter_norway          televoter norway                         0        0
# televoter_poland          televoter poland                         0        2
# televoter_portugal        televoter portugal                       0        3
# televoter_romania         televoter romania                        0        0
# televoter_spain           televoter spain                          2        0
# televoter_sweden          televoter sweden                         0        0
# televoter_the netherlands televoter the netherlands                0        0
# televoter_ukraine         televoter ukraine                        0        0
# televoter_united kingdom  televoter united kingdom                 0        0
#
# To                                                   united kingdom
# voter_country             voter     From
# jury_bulgaria             jury      bulgaria                      0
# televoter_armenia         televoter armenia                       0
# televoter_australia       televoter australia                     3
# televoter_austria         televoter austria                       0
# televoter_azerbaijan      televoter azerbaijan                    0
# televoter_belarus         televoter belarus                       0
# televoter_belgium         televoter belgium                       0
# televoter_bulgaria        televoter bulgaria                      0
# televoter_croatia         televoter croatia                       0
# televoter_cyprus          televoter cyprus                        0
# televoter_denmark         televoter denmark                       0
# televoter_france          televoter france                        0
# televoter_germany         televoter germany                       0
# televoter_greece          televoter greece                        0
# televoter_hungary         televoter hungary                       0
# televoter_israel          televoter israel                        0
# televoter_italy           televoter italy                         0
# televoter_moldova         televoter moldova                       0
# televoter_norway          televoter norway                        0
# televoter_poland          televoter poland                        0
# televoter_portugal        televoter portugal                      0
# televoter_romania         televoter romania                       0
# televoter_spain           televoter spain                         1
# televoter_sweden          televoter sweden                        0
# televoter_the netherlands televoter the netherlands               0
# televoter_ukraine         televoter ukraine                       0
# televoter_united kingdom  televoter united kingdom                0

# %%
# temporal analysis of results
df_cosinesim_combined = pd.concat(df_cosinesim_by_year_list, ignore_index=True)
country_counts = df_cosinesim_combined['Country'].value_counts().reset_index()
country_counts.columns = ['Country', 'Count']
country_counts_5 = list(country_counts[country_counts.Count == 5].Country)
df_cosinesim_combined_subset = df_cosinesim_combined[df_cosinesim_combined.Country.isin(country_counts_5)]

fig, ax1 = plt.subplots(1,1)
fig.set_size_inches(16,8)
sns.lineplot(
    data=df_cosinesim_combined_subset[df_cosinesim_combined_subset.Year<=2019], 
    x="Year", y="Similarity", 
    hue="Country", palette="Paired", ax=ax1)
sns.lineplot(
    data=df_cosinesim_combined_subset[df_cosinesim_combined_subset.Year>=2019], 
    x="Year", y="Similarity", linestyle="dashed",
    hue="Country", palette="Paired", ax=ax1)

handles, labels = ax1.get_legend_handles_labels()
num_legend = int(len(labels)/2)
ax1.legend(handles[:num_legend], labels[:num_legend], bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0, labels=country_counts_5.sort())
ax1.set_title("Temporal comparison of voting trends for countries present in previous 5 Eurovision Song Contests")
plt.show()

# %% [markdown]
# ##### Comments:
# Generally, the similarity scores are high for Cyprus compared to other countries.
#
# We observe an interesting phenomena where the similarity scores decreased in 2018 across countries, some more than others. In 2018, there were many differences in voting between the televoters and jury, (this can also be observed in the points difference heatmap).

# %% [markdown]
# ## 4. Visualising the Embedding Space

# %% [markdown]
# This section explores whether any insights can be gained from visually comparing the voting patterns in an embedding space. For this, we apply two common techniques - PCA and TSNE.
#
# PCA is a linear method of dimensionality reduction, which seeks to maximise the variance in the data.
# When we visualise data with PCA, it's worth noting that a 2D projection may not be completely accurate, as we're operating in multidimensional space (a 3D projection will provide a better view of the differences between data points). With PCA it is generally best practice to normalize the data beforehand (if the features have not been measured to the same scale). Technically, the points are all measured to the same scale, but as the scores for some countries may be more limited in range, we'll normalize the data to bring everything to a common scale. At a minimum, the explained variance of PCA should be at least 70% to be a good representation of the variability in the data. For smaller values, there are limitations with interpreting PCA.
#
#
#
# TSNE is a non-linear method of dimensionality reduction.
#
# We also explore some spproaches to clustering ...

# %%
def normalize_data(np_matrix):
    """Normalize the data - center it on mean zero with unit variance"""
    scaler = preprocessing.StandardScaler()
    np_matrix_normalized = scaler.fit_transform(np_matrix)
    return np_matrix_normalized

# %%
def covariance_matrix(np_matrix, np_matrix_normalized):
    """Compute and compare the covariance matrices for normalised 
    and non-normalised data
    """
    np_cov = np.cov(np_matrix, rowvar=False)
    np_norm_cov = np.cov(np_matrix_normalized, rowvar=False)
    fig, (ax1, ax2) = plt.subplots(1,2)
    fig.set_size_inches(16,6)
    sns.heatmap(np_cov, ax=ax1)
    sns.heatmap(np_norm_cov, ax=ax2)
    plt.show()

# %%
# compare normalized and non-normalized covariance matrices
years = [2016, 2017, 2018, 2019, 2021]
for year in years:
    df_wide, np_matrix, country_labels, voter_country_labels = create_df_wide_by_year(data, year=year)
    np_matrix_normalized = normalize_data(np_matrix)
    covariance_matrix(np_matrix, np_matrix_normalized)

# %% [markdown]
# ##### Comments:
# When we compare the covariance matrixes between non-normalized and normalized data, we can see that the variances of each feature (on the diagonal) varies with non-normalized data, but is the same (takes a value of 1) when we normalize the data. This can potentially skew the choice of axes for the principal components, so we'll work with normalized data going forward

# %%
def pca(np_matrix_normalized, np_matrix_col_names, evr=0.7):
    """Compute the principal components for plotting. Specify the required
    explained variance ratio (between 0 and 1) to compute the number of
    principal components.
    """
    pca = decomposition.PCA(n_components=evr)
    pca.fit(np_matrix_normalized)
    pca_transformed_values = pca.transform(np_matrix_normalized)
    pca_transformed_values_3d = pca_transformed_values[:,0:3]
    num_pc = pca.components_.T.shape[1]
    col_names = list(['PC'+str(i+1) for i in range(0,num_pc)])
    loadings = pd.DataFrame(pca.components_.T,
        columns=col_names,
        index=np_matrix_col_names) # how the original variables are correlated to the new PCAs
#     print("Number of Principal Components: ", num_pc)
#     print("PCA Explained Variance: ", np.sum(pca.explained_variance_ratio_))
#     print("PCA Explained Variance Ratio: ", pca.explained_variance_ratio_)
#     print("PCA Explained Variance Ratio (Top 3 Components): ", np.sum(pca.explained_variance_ratio_[0:3]))
#     print("PCA Loadings: ")
#     print(loadings)
    return pca_transformed_values, pca_transformed_values_3d

# %% [markdown]
# ##### Comments:
# To achieve a 70% explained variance ratio, we need 9-10 principal components. With 3 PCs, only 32%-38% of the variance is captured, so a 3D projection may not be a good representation of the data

# %%
def tsne(np_matrix_normalized):
    """Compute tsne for plotting"""
    perplexity = (np_matrix_normalized.shape[0]) ** 0.5
    tsne_transformed_values = manifold.TSNE(
        n_components=3, 
        perplexity=perplexity, learning_rate=100, random_state=1).fit_transform(np_matrix)
#    print(tsne_transformed_values)
    return tsne_transformed_values

# %%
def k_means_clustering(np_matrix):
    """Compute clusters
    Note: flat elbow seems to suggest there's not much clustering activity
    """
    distortions = []
    K = range(2,26)
    # calculate kmeans and plot to determine number of cluster via elbow method
    for k in K:
        kmeanModel = cluster.KMeans(n_clusters=k, random_state=1)
        kmeanModel.fit(np_matrix)
        distortions.append(kmeanModel.inertia_)
    # plt.figure(figsize=(16,8))
    # plt.plot(K, distortions, 'bx-')
    # plt.xlabel('k')
    # plt.ylabel('Distortion')
    # plt.title('The Elbow Method showing the optimal k')
    # plt.show()
    kmeans = (cluster.KMeans(n_clusters=4, random_state=0)
        .fit(np_matrix))
    labels = kmeans.labels_
#    print(labels)
    return labels

# %%
def merge_pca_k_means_to_df(df, pca_values, tsne_values, k_means_labels):
    df['pca1'] = pca_values[:,0]
    df['pca2'] = pca_values[:,1]
    df['pca3'] = pca_values[:,2]
    df['tsne1'] = tsne_values[:,0]
    df['tsne2'] = tsne_values[:,1]
    df['tsne3'] = tsne_values[:,2]
    df['kmeans_cluster'] = k_means_labels
    df = df.reset_index()
    df = df[['voter_country','voter','From','pca1','pca2','pca3','tsne1','tsne2','tsne3','kmeans_cluster']]
    df['kmeans_cluster'] = df.kmeans_cluster.astype(str)
    return df

# %%
def plot_chart_2d(df,year):
    """Plot diagram"""
    #plot 2d chart
    fig, ax1 = plt.subplots(1,1)
    sns.scatterplot(x="pca1", y="pca2", hue="kmeans_cluster", style="voter", palette="Set2", s=100, data=df, ax=ax1)
    ax1.legend(bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0)
    for line in range(0,df.shape[0]):
        ax1.text(df.pca1[line]+0, df.pca2[line], df.From[line], horizontalalignment='left', size='large', color='black')
    ax1.set_title('PCA Projection for Eurovision Song Contest Voting in {}'.format(year))
    fig.set_size_inches(16,16)
    plt.show()
    
#     fig, ax2 = plt.subplots(1,1)
#     sns.scatterplot(x="tsne1", y="tsne2", hue="kmeans_cluster", style="voter", palette="Set2", s=100, data=df, ax=ax2)
#     for line in range(0,df.shape[0]):
#         ax2.text(df.tsne1[line]+0, df.tsne2[line], df.From[line], horizontalalignment='left', size='large', color='black')
#     ax2.legend(bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0)
#     ax2.set_title('TSNE Projection')    
#     fig.set_size_inches(16,16)
#     plt.show()

def plot_chart_3d(df, year):    
    fig = px.scatter_3d(df, x='pca1', y='pca2', z='pca3', 
        color='kmeans_cluster', symbol='voter', hover_name='From', 
        width=800, height=800, title="PCA Projection for Eurovision Song Contest Voting in {}".format(year))
    fig.update_layout(coloraxis_colorbar=dict(yanchor="top", y=1, x=0,
                                          ticks="outside",
                                          ticksuffix=" bills"))
    fig.show()

#     fig = px.scatter_3d(df, x='tsne1', y='tsne2', z='tsne3', color='kmeans_cluster', symbol='voter', hover_name='From')
#     fig.show()

# %%
years = [2016, 2017, 2018, 2019, 2021]

for year in years:
    df_wide, np_matrix, country_labels, voter_country_labels = create_df_wide_by_year(data, year=year)
    np_matrix_normalized = normalize_data(np_matrix)
    pca_values, pca_values_3d = pca(np_matrix_normalized, country_labels)
    tsne_values = tsne(np_matrix_normalized)
    k_means_labels = k_means_clustering(np_matrix_normalized)
    df_plotting = merge_pca_k_means_to_df(df_wide, pca_values, tsne_values, k_means_labels)
    plot_chart_2d(df_plotting, year)
    plot_chart_3d(df_plotting, year)
# Out:
# <div>                            <div id="9ae86f47-635b-4a55-8641-c7d318eb3f75" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9ae86f47-635b-4a55-8641-c7d318eb3f75")) {                    Plotly.newPlot(                        "9ae86f47-635b-4a55-8641-c7d318eb3f75",                        [{"hovertemplate": "<b>%{hovertext}</b><br><br>kmeans_cluster=2<br>voter=jury<br>pca1=%{x}<br>pca2=%{y}<br>pca3=%{z}<extra></extra>", "hovertext": ["armenia", "belgium", "croatia", "cyprus", "france", "malta", "russia", "spain", "sweden", "the netherlands", "united kingdom"], "legendgroup": "2, jury", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "2, jury", "scene": "scene", "showlegend": true, "type": "scatter3d", "x": [2.197329005216061, 1.6479227305364175, 2.5682687571146023, 1.3262810388132542, 0.7716502756047791, 1.11387913534191, 1.9414238484410096, 1.6163172626816702, 2.25532908188098, 0.9604933657899508, 0.6619578667258079], "y": [1.5171054360927705, 1.3384390080265873, 1.2769747708981711, 1.8956325945327948, 1.4678102248828748, 4.301960621931547, 2.6372532421405386, 2.71053984290934, 1.352685970727036, -0.5428915371585625, -0.45292511595023277], "z": [-2.5157642868814385, -0.13069394377503835, 1.1357388496897909, 1.0967994667478491, 1.8431335564815574, -1.8010233448237094, -1.4837472504217342, 1.9776184375880388, 1.2401818572253662, 1.237081069605153, -2.7854310230513697]}, {"hovertemplate": "<b>%{hovertext}</b><br><br>kmeans_cluster=2<br>voter=televoter<br>pca1=%{x}<br>pca2=%{y}<br>pca3=%{z}<extra></extra>", "hovertext": ["malta"], "legendgroup": "2, televoter", "marker": {"color": "#636efa", "symbol": "diamond"}, "mode": "markers", "name": "2, televoter", "scene": "scene", "showlegend": true, "type": "scatter3d", "x": [0.2657132997509646], "y": [1.8040506321677081], "z": [1.1510590352419268]}, {"hovertemplate": "<b>%{hovertext}</b><br><br>kmeans_cluster=0<br>voter=jury<br>pca1=%{x}<br>pca2=%{y}<br>pca3=%{z}<extra></extra>", "hovertext": ["australia", "austria", "bulgaria", "georgia", "germany", "hungary", "italy", "latvia", "lithuania", "poland", "serbia", "ukraine"], "legendgroup": "0, jury", "marker": {"color": "#EF553B", "symbol": "circle"}, "mode": "markers", "name": "0, jury", "scene": "scene", "showlegend": true, "type": "scatter3d", "x": [2.5752957645143804, 3.053055608181447, 1.364489737315611, 1.0151786277828596, 1.7363701514214878, 3.2063466037347363, 2.799595343859355, -0.4332566621117132, 1.212911845835506, 2.3666433698571185, 1.4494308362321477, 2.092756256685102], "y": [-0.5166765439687109, 0.017700888202115697, 0.026798920230464, -3.792519456111634, -2.767705985165162, -1.5318970909517087, -1.0289001825479165, -1.559516205381424, -2.347060245387358, -2.6051077863750383, -0.9049170643014395, -3.251664766804938], "z": [-1.975131127980532, 2.872860048400606, 0.08856151095308573, 0.565501040401023, -0.06109368023355933, 1.2709753988003998, -1.4647707549875135, 1.000305912161492, -2.0145876474801034, -2.2531468019350016, -0.18166804056613267, -0.6852264052903445]}, {"hovertemplate": "<b>%{hovertext}</b><br><br>kmeans_cluster=1<br>voter=jury<br>pca1=%{x}<br>pca2=%{y}<br>pca3=%{z}<extra></extra>", "hovertext": ["azerbaijan", "czech republic", "israel"], "legendgroup": "1, jury", "marker": {"color": "#00cc96", "symbol": "circle"}, "mode": "markers", "name": "1, jury", "scene": "scene", "showlegend": true, "type": "scatter3d", "x": [-0.45327594208947103, 2.5718892240319446, 1.4651106919538437], "y": [-0.20227546005695668, 0.5160999294043453, -0.7928271014859427], "z": [-0.10046931673696433, 4.487448890634835, -1.0413545316785706]}, {"hovertemplate": "<b>%{hovertext}</b><br><br>kmeans_cluster=1<br>voter=televoter<br>pca1=%{x}<br>pca2=%{y}<br>pca3=%{z}<extra> ...
# <div>                            <div id="e07616bc-3382-4919-8552-30b296ceaa9a" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e07616bc-3382-4919-8552-30b296ceaa9a")) {                    Plotly.newPlot(                        "e07616bc-3382-4919-8552-30b296ceaa9a",                        [{"hovertemplate": "<b>%{hovertext}</b><br><br>kmeans_cluster=1<br>voter=jury<br>pca1=%{x}<br>pca2=%{y}<br>pca3=%{z}<extra></extra>", "hovertext": ["armenia", "israel", "ukraine"], "legendgroup": "1, jury", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "1, jury", "scene": "scene", "showlegend": true, "type": "scatter3d", "x": [-0.7351738395395659, 0.2658839178609165, 1.4232996472226442], "y": [0.9727028870507681, -0.8346594902336228, 1.6112722674111533], "z": [-2.428686229114981, -0.9602505399792477, 1.5249200691944043]}, {"hovertemplate": "<b>%{hovertext}</b><br><br>kmeans_cluster=1<br>voter=televoter<br>pca1=%{x}<br>pca2=%{y}<br>pca3=%{z}<extra></extra>", "hovertext": ["armenia", "australia", "austria", "azerbaijan", "belarus", "belgium", "bulgaria", "croatia", "cyprus", "denmark", "france", "germany", "greece", "hungary", "israel", "italy", "norway", "poland", "portugal", "romania", "spain", "sweden", "the netherlands", "ukraine", "united kingdom"], "legendgroup": "1, televoter", "marker": {"color": "#636efa", "symbol": "diamond"}, "mode": "markers", "name": "1, televoter", "scene": "scene", "showlegend": true, "type": "scatter3d", "x": [1.446453420378927, 0.177923089587651, 2.274992518259681, 1.7191693120547344, 1.3451989306729348, 0.41823310926700263, 2.8458806743936687, 1.8662854070421455, 0.8561140149849581, -0.4431422131928502, 1.7735770815513312, 2.611478855618543, 1.0836259511501387, 2.074528443118765, 1.616430830332288, 3.331963758949339, 1.647527871424158, 2.07605726496437, 3.9450642644586615, 2.248797892745252, 0.8640104175754217, 1.5216974412445372, 1.8779090063343773, 1.515955158027072, 1.6808800321179604], "y": [-0.11273211718595572, -0.8979509513493366, -1.4043486920591246, -1.2395342809456051, -1.173179778373354, -0.4848648693451192, 1.176504910467, -1.5187491451357829, 0.02665173823666007, -1.0225703310558512, 0.8471877471825076, -1.088801105824302, -0.2259961858852631, -1.1623906063136364, -1.3439745716914482, 0.5769067981088707, -1.1783390163979444, -0.8259953291926804, 0.9995545090121245, -1.1466078386336678, -1.4707274848039626, -0.9008964379503395, -1.5781844831255636, 0.3947999196417441, -0.4106929356006266], "z": [-2.899791686219161, 0.05141036435704971, 1.1181250240615068, -0.6444839443546347, -0.30138649454513416, 1.159062694645428, -1.7600114541109526, -0.18341758956831003, -1.5086366158344433, -0.6414539602504058, 0.24143796626966899, 1.7370851624278238, -2.558069631304092, 0.002870804822139479, -0.7661792477509121, 3.1099179179706096, 0.7216215459170771, 0.9059363144126539, -1.1780878220132271, -0.20346141702506115, -0.8075439268550096, 1.3800172706929457, 0.6765500805596828, -0.582373737157105, 2.714101852989136]}, {"hovertemplate": "<b>%{hovertext}</b><br><br>kmeans_cluster=3<br>voter=jury<br>pca1=%{x}<br>pca2=%{y}<br>pca3=%{z}<extra></extra>", "hovertext": ["australia", "austria", "belarus", "belgium", "croatia", "cyprus", "denmark", "france", "germany", "hungary", "norway", "poland", "romania", "spain", "sweden", "the netherlands", "united kingdom"], "legendgroup": "3, jury", "marker": {"color": "#EF553B", "symbol": "circle"}, "mode": "markers", "name": "3, jury", "scene": "scene", "showlegend": true, "type": "scatter3d", "x": [-2.400823297949854, -1.1385075254090418, -3.7306198974451394, -3.1426912674733147, -1.9169357836389485, -1.147030485178797, -3.636002307210523, -2.892525899817248, -3.5427949758902626, -3.632224719480238, -2.4597070 ...
# <div>                            <div id="6b9f42b2-486e-4f20-8a7d-9465a2939987" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6b9f42b2-486e-4f20-8a7d-9465a2939987")) {                    Plotly.newPlot(                        "6b9f42b2-486e-4f20-8a7d-9465a2939987",                        [{"hovertemplate": "<b>%{hovertext}</b><br><br>kmeans_cluster=3<br>voter=jury<br>pca1=%{x}<br>pca2=%{y}<br>pca3=%{z}<extra></extra>", "hovertext": ["albania", "finland", "spain"], "legendgroup": "3, jury", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "3, jury", "scene": "scene", "showlegend": true, "type": "scatter3d", "x": [-1.303754947809722, 0.6061085239202573, 0.18119584185192444], "y": [0.9988635839136533, 0.4274678472913156, 0.03680940873318215], "z": [-1.7652904324459866, -1.9814190063732726, -1.6036960908120257]}, {"hovertemplate": "<b>%{hovertext}</b><br><br>kmeans_cluster=3<br>voter=televoter<br>pca1=%{x}<br>pca2=%{y}<br>pca3=%{z}<extra></extra>", "hovertext": ["albania", "australia", "austria", "bulgaria", "cyprus", "estonia", "finland", "germany", "hungary", "lithuania", "moldova", "serbia", "slovenia", "spain", "sweden", "the netherlands", "ukraine", "united kingdom"], "legendgroup": "3, televoter", "marker": {"color": "#636efa", "symbol": "diamond"}, "mode": "markers", "name": "3, televoter", "scene": "scene", "showlegend": true, "type": "scatter3d", "x": [-0.4450109564271739, -1.0262196367225502, -2.918559279180856, -3.2035473097437923, -1.4467731201315164, -0.7007195839828477, -2.141049082367801, -1.6292907005868997, -1.7418128671882713, -1.4685978946141978, -2.7708350282294507, -2.51510585931729, -3.074867126065022, -1.7823084197360701, -0.25685661259064974, -1.4502181801810718, -2.6453964229368583, -0.6122752656597873], "y": [0.6439134322310698, -2.1952244395047877, -1.5190764124933123, 0.3397380823661686, -0.4545173364683095, -3.231652819796462, -0.20517720709025872, -1.494416766831867, -1.8643393485448103, 0.4552820685687956, 0.0876881842039544, -1.786869779162025, -1.9945183483622062, -0.35544699222883747, -3.4373378207159733, -1.4182542758220837, -0.13194532271639414, -0.8473781243541223], "z": [-2.1258444073953373, -0.5577244130558793, 1.2465877498221782, 0.7296666841773752, -1.683528040560168, 1.0239454078709413, 2.0016457263505654, -0.3310263727272012, 0.6440383215369214, 0.9579392915752676, -1.2808388048387078, 0.8403860532770633, 1.563635069802212, -1.834708859708963, -0.38819943142488256, -0.2604080396553949, 0.7298314900645348, -2.094986509738841]}, {"hovertemplate": "<b>%{hovertext}</b><br><br>kmeans_cluster=1<br>voter=jury<br>pca1=%{x}<br>pca2=%{y}<br>pca3=%{z}<extra></extra>", "hovertext": ["australia", "austria", "bulgaria", "czech republic", "estonia", "hungary", "ireland", "italy", "moldova", "portugal", "serbia", "the netherlands", "united kingdom"], "legendgroup": "1, jury", "marker": {"color": "#EF553B", "symbol": "circle"}, "mode": "markers", "name": "1, jury", "scene": "scene", "showlegend": true, "type": "scatter3d", "x": [1.6911826976209337, 1.2485109293167493, 1.2207259986043448, 1.7578615062259066, 2.0734748748200875, 1.8870880554564138, 0.41956069483770003, 1.0460995487714548, 0.09361119190383739, 1.0297298938688082, 1.3752326412009135, 1.9562371401761482, 1.4024787084320245], "y": [2.255181456177782, 0.3575692925586512, -0.5334936152773646, -0.7304513656697595, -0.594859095259183, -1.1613755513244108, 1.73400389796908, -2.0873519306430466, 1.6336503801470463, 1.9108351871775395, 0.6469237891588675, 0.11527736814756202, -0.01681445155292828], "z": [0.8819045299247557, -0.6298104096409132, 0.08749957832174732, -0.3129848517891858, -1.9076047575687716, 1.2358557027450405, -3.474091730341998, -0.1977788115389459, -2.181670183044452 ...
# <div>                            <div id="0837943d-45b8-4705-bc7c-a46ceed1ca52" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0837943d-45b8-4705-bc7c-a46ceed1ca52")) {                    Plotly.newPlot(                        "0837943d-45b8-4705-bc7c-a46ceed1ca52",                        [{"hovertemplate": "<b>%{hovertext}</b><br><br>kmeans_cluster=2<br>voter=jury<br>pca1=%{x}<br>pca2=%{y}<br>pca3=%{z}<extra></extra>", "hovertext": ["albania", "australia", "denmark", "estonia", "france", "iceland", "israel", "italy", "norway", "serbia", "slovenia", "spain", "switzerland", "the netherlands", "united kingdom"], "legendgroup": "2, jury", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "2, jury", "scene": "scene", "showlegend": true, "type": "scatter3d", "x": [0.3874806593873752, -2.2908010349653347, -2.138853196030747, -1.7901131940417039, -1.5890991131563534, -2.321242337189478, -1.2491215452225957, -1.539471077900724, -3.344632021600713, -1.984605896445091, -1.931762557670781, -1.2479110804902769, -2.2534393123065564, -0.8096069484254287, -1.8264503929696205], "y": [-2.2979119332592206, -1.8733513194255458, -1.3389997394587703, -1.37374203213506, -0.9854820780564575, -1.4452054259229987, -0.8316912994111108, -2.3750842536146406, -3.379978213579334, -1.267798468625791, -2.2159924008523495, -1.4476656486598185, -1.0859851232877484, -1.081953199183323, -1.3629643680034955], "z": [-1.1711741653450989, -0.3295817970238824, -0.36188979361863616, -0.4373590553895885, -0.2269170007987179, -0.6095660545682337, -0.1708995210383013, 1.9861676446563692, -1.232898685989204, -0.4631962504389305, -0.9242102446837006, -0.5567348479198153, -1.207253759510602, -0.42895084638780895, -0.039602434256480766]}, {"hovertemplate": "<b>%{hovertext}</b><br><br>kmeans_cluster=0<br>voter=jury<br>pca1=%{x}<br>pca2=%{y}<br>pca3=%{z}<extra></extra>", "hovertext": ["azerbaijan", "belarus", "cyprus", "greece", "malta", "russia", "san marino"], "legendgroup": "0, jury", "marker": {"color": "#EF553B", "symbol": "circle"}, "mode": "markers", "name": "0, jury", "scene": "scene", "showlegend": true, "type": "scatter3d", "x": [3.678739282694064, 1.803286015535666, 1.8009220175329244, 3.9049693480285024, 2.045877378613509, 4.3663332197007545, 3.1991048957839268], "y": [-1.6883857483014209, -2.5996203493385406, -1.5353337410858625, -1.9115278030861562, -1.5076992515987213, -3.423555316174699, -0.3158436949854466], "z": [0.5314615442691211, -0.5451743377153029, -1.5725845687384306, 0.8703334843403684, -1.1277740300983359, 2.5530465207611845, -0.6138357929824179]}, {"hovertemplate": "<b>%{hovertext}</b><br><br>kmeans_cluster=0<br>voter=televoter<br>pca1=%{x}<br>pca2=%{y}<br>pca3=%{z}<extra></extra>", "hovertext": ["albania", "azerbaijan", "san marino"], "legendgroup": "0, televoter", "marker": {"color": "#EF553B", "symbol": "diamond"}, "mode": "markers", "name": "0, televoter", "scene": "scene", "showlegend": true, "type": "scatter3d", "x": [1.9231084197212378, 2.6622787106523003, 2.6486118780444823], "y": [0.09360517997460005, 0.14793851347208897, -0.04299959229016319], "z": [-0.33127383074387196, 0.27951065362433536, -1.5448749733590217]}, {"hovertemplate": "<b>%{hovertext}</b><br><br>kmeans_cluster=3<br>voter=jury<br>pca1=%{x}<br>pca2=%{y}<br>pca3=%{z}<extra></extra>", "hovertext": ["czech republic"], "legendgroup": "3, jury", "marker": {"color": "#00cc96", "symbol": "circle"}, "mode": "markers", "name": "3, jury", "scene": "scene", "showlegend": true, "type": "scatter3d", "x": [-0.2822801880743091], "y": [-1.4281957779419743], "z": [1.10265690066467]}, {"hovertemplate": "<b>%{hovertext}</b><br><br>kmeans_cluster=3<br>voter=televoter<br>pca1=%{x}<br>pca2=%{y}<br>pca3=%{z}<extra></extra>", "hovertext" ...
# <div>                            <div id="f9414ea3-af8e-44b1-a38c-ee1a0eb1e6e0" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f9414ea3-af8e-44b1-a38c-ee1a0eb1e6e0")) {                    Plotly.newPlot(                        "f9414ea3-af8e-44b1-a38c-ee1a0eb1e6e0",                        [{"hovertemplate": "<b>%{hovertext}</b><br><br>kmeans_cluster=0<br>voter=jury<br>pca1=%{x}<br>pca2=%{y}<br>pca3=%{z}<extra></extra>", "hovertext": ["albania", "azerbaijan", "cyprus", "france", "greece", "israel", "moldova", "portugal", "russia", "the netherlands"], "legendgroup": "0, jury", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "0, jury", "scene": "scene", "showlegend": true, "type": "scatter3d", "x": [1.9150660873282708, 2.090113098942795, 2.1078305391682735, 3.049605707418089, 3.3021979117072933, 0.8736966121728955, 2.5830839089795443, 2.1234128303510516, 3.2788950906577066, 1.3753692715753674], "y": [0.011228012092296125, 0.34860416916116566, -0.5768258116359297, -1.1691352872398992, 0.7840814061357047, -2.5186640352272573, -1.6211277247284273, -2.123117199939614, 1.4813855369335744, -3.0204638097387413], "z": [-2.041637240661391, -0.9376243346399258, -0.7833181524766741, 0.4026126934442781, -1.9417364480837611, -1.2152161112822213, -1.2130766350921158, 1.159022484824767, -1.5518769844574445, 0.18961090947453835]}, {"hovertemplate": "<b>%{hovertext}</b><br><br>kmeans_cluster=3<br>voter=jury<br>pca1=%{x}<br>pca2=%{y}<br>pca3=%{z}<extra></extra>", "hovertext": ["belgium", "iceland", "malta"], "legendgroup": "3, jury", "marker": {"color": "#EF553B", "symbol": "circle"}, "mode": "markers", "name": "3, jury", "scene": "scene", "showlegend": true, "type": "scatter3d", "x": [-0.6554038625502807, 0.7543254917908719, -0.0687838644617466], "y": [-1.1135871143294798, 0.03766122595798297, 1.3657269571587936], "z": [-0.6713679735189695, 0.24165609477507816, -0.4502425289872661]}, {"hovertemplate": "<b>%{hovertext}</b><br><br>kmeans_cluster=3<br>voter=televoter<br>pca1=%{x}<br>pca2=%{y}<br>pca3=%{z}<extra></extra>", "hovertext": ["albania", "azerbaijan", "bulgaria", "cyprus", "france", "greece", "israel", "italy", "lithuania", "moldova", "portugal", "russia", "san marino", "serbia"], "legendgroup": "3, televoter", "marker": {"color": "#EF553B", "symbol": "diamond"}, "mode": "markers", "name": "3, televoter", "scene": "scene", "showlegend": true, "type": "scatter3d", "x": [1.0073719168075226, -0.7762983189825239, -1.5152680592875958, 0.1322848778020834, -0.2275553421567807, -0.556054897543206, -0.6640469923290881, -2.378193669763807, -2.061409810895548, -0.7171821871682942, -0.7437489055508886, -0.740732310551731, 0.632318567142763, -1.0449076570109443], "y": [1.5688602769779603, 0.5949464027403271, 1.6564201189677281, 0.791378998532661, 1.7630527187626293, 1.7347407174154035, -0.42541252906560134, 1.1617782678597808, 0.16580093909271013, 0.8097306148464367, 1.5021632534411586, 1.724783946138727, 2.380601091223794, 0.8482970449798124], "z": [-1.253965616221523, 0.27868051784702125, -1.4858316194935122, -0.6045118160425478, 1.1255714127500014, -2.3731083630136656, -1.5559710695329196, -0.14645740301688318, -0.4022476874428237, -1.6158921202757894, -0.6709408914342303, -2.425902126426519, -1.924004343687273, -1.5203888598287547]}, {"hovertemplate": "<b>%{hovertext}</b><br><br>kmeans_cluster=2<br>voter=jury<br>pca1=%{x}<br>pca2=%{y}<br>pca3=%{z}<extra></extra>", "hovertext": ["bulgaria"], "legendgroup": "2, jury", "marker": {"color": "#00cc96", "symbol": "circle"}, "mode": "markers", "name": "2, jury", "scene": "scene", "showlegend": true, "type": "scatter3d", "x": [5.008368030393693], "y": [5.657394649026896], "z": [5.589772045400368]}, {"hovertemplate": "<b>%{hovertext}</b><br>< ...

# %% [markdown]
# ##### Comments
# The PCA projection reveals some patterns we saw earlier. (e.g. Bulgaria jury with a very different voting pattern to others in 2017). Bulgarian jury voting appears to be quite different in 2017 and 2021 (as shown by how far the point is away from the others).
#
# The TSNE projections require further tuning of the hyperparameters (perplexity and learning rate) to get a more useful projection.
